# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px 
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv("business.csv")

# %%
df1
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
# ...

# %%
df2 = pd.read_csv("economy.csv")

# %%
df2
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df1.columns
# Out:
# Index(['date', 'airline', 'ch_code', 'num_code', 'dep_time', 'from',
#        'time_taken', 'stop', 'arr_time', 'to', 'price'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['date', 'airline', 'ch_code', 'num_code', 'dep_time', 'from',
#        'time_taken', 'stop', 'arr_time', 'to', 'price'],
#       dtype='object')

# %%
df = df1.append([df2])
# Out:
# C:\Users\Md Imran\AppData\Local\Temp\ipykernel_6240\1270716999.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append([df2])

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300261 entries, 0 to 206773
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 27.5+ MB

# %%
df.describe()
# Out:
#             num_code
# count  300261.000000
# mean     1417.771709
# std      1974.514439
# min       101.000000
# 25%       637.000000
# 50%       818.000000
# 75%       927.000000
# max      9991.000000

# %%
# Describing the categorical variables
df_categorical_variables = pd.DataFrame (df, columns= ['date', 'airline', 'ch_code', 'dep_time', 'from',
       'time_taken', 'stop', 'arr_time', 'to', 'price'])

df_categorical_variables.describe()
# Out:
#               date  airline ch_code dep_time    from time_taken  \
# count       300261   300261  300261   300261  300261     300261
# unique          49        8       8      251       6        483
# top     07-03-2022  Vistara      UK    07:00   Delhi    02h 10m
# freq          6633   127859  127859     8760   61345       4242
#
#                                                      stop arr_time      to  \
# count                                              300261   300261  300261
# unique                                                 40      266       6
# top     1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:55  Mumbai
# freq                                               243603     9194   59109
#
#          price
# count   300261
# unique   12165
# top     54,608
# freq      1445

# %%
df["day"] = pd.to_datetime(df.date).dt.day
df["month"] = pd.to_datetime(df.date).dt.month
df["year"] = pd.to_datetime(df.date).dt.year
# Out:
# C:\Users\Md Imran\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Md Imran\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Md Imran\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300261 entries, 0 to 206773
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  object
#  11  day         300261 non-null  int64
#  12  month       300261 non-null  int64
#  13  year        300261 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 34.4+ MB

# %%
# Since we have converted Date_of_Journey column into integers, Now we can drop as it is of no use.
df.drop(["date"], axis = 1, inplace = True)

# %%
df
# Out:
#           airline ch_code  num_code dep_time     from time_taken  \
# 0       Air India      AI       868    18:00    Delhi    02h 00m
# 1       Air India      AI       624    19:00    Delhi    02h 15m
# 2       Air India      AI       531    20:00    Delhi    24h 45m
# 3       Air India      AI       839    21:25    Delhi    26h 30m
# 4       Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...     ...       ...      ...      ...        ...
# 206769    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773    Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     20:00     Mumbai
# ...

# %%
df["arr_time"].value_counts()
# Out:
# 19:55    9194
# 20:55    6363
# 22:45    5282
# 09:40    5185
# 08:50    5125
#          ...
# 06:20      20
# 03:45      18
# 05:45      15
# 05:20       5
# 04:50       5
# Name: arr_time, Length: 266, dtype: int64

# %%
# Extracting Hours
df["Dep_hour"] = pd.to_datetime(df["dep_time"]).dt.hour

# Extracting Minutes
df["Dep_min"] = pd.to_datetime(df["dep_time"]).dt.minute

# Now we can drop Dep_Time as it is of no use
df.drop(["dep_time"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      airline ch_code  num_code   from time_taken  \
# 0  Air India      AI       868  Delhi    02h 00m
# 1  Air India      AI       624  Delhi    02h 15m
# 2  Air India      AI       531  Delhi    24h 45m
# 3  Air India      AI       839  Delhi    26h 30m
# 4  Air India      AI       544  Delhi    06h 40m
#
#                                                 stop arr_time      to   price  \
# 0                                          non-stop     20:00  Mumbai  25,612
# 1                                          non-stop     21:15  Mumbai  25,612
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45  Mumbai  42,220
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  44,450
# 4  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  46,690
#
#    day  month  year  Dep_hour  Dep_min
# 0    2     11  2022        18        0
# 1    2     11  2022        19        0
# 2    2     11  2022        20        0
# ...

# %%
# Extracting Hours
df["Arrival_hour"] = pd.to_datetime(df.arr_time).dt.hour

# Extracting Minutes
df["Arrival_min"] = pd.to_datetime(df.arr_time).dt.minute

# Now we can drop Arrival_Time as it is of no use
df.drop(["arr_time"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      airline ch_code  num_code   from time_taken  \
# 0  Air India      AI       868  Delhi    02h 00m
# 1  Air India      AI       624  Delhi    02h 15m
# 2  Air India      AI       531  Delhi    24h 45m
# 3  Air India      AI       839  Delhi    26h 30m
# 4  Air India      AI       544  Delhi    06h 40m
#
#                                                 stop      to   price  day  \
# 0                                          non-stop   Mumbai  25,612    2
# 1                                          non-stop   Mumbai  25,612    2
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...  Mumbai  42,220    2
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...  Mumbai  44,450    2
# 4  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...  Mumbai  46,690    2
#
#    month  year  Dep_hour  Dep_min  Arrival_hour  Arrival_min
# 0     11  2022        18        0            20            0
# 1     11  2022        19        0            21           15
# ...

# %%
df['stop'].unique()
# Out:
# array(['non-stop ',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IDR\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Chennai\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Lucknow\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia STV\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Hyderabad\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAY\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '2+-stop',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Guwahati\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAU\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia VTZ\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia NDC\n\t\t\t\t\t\t\t\t\t\t\t\t',
# ...

# %%
df['stop'].nunique()
# Out:
# 40

# %%
df['stop'] = df['stop'].map({'non-stop ' : 0,'1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t' : 1,
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IDR\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 IDR',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 IXU',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Chennai\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Chennai',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Lucknow\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Lucknow',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia STV\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 STV',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Hyderabad\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Hyderabad',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAY\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 GAY',
       '2+-stop' : 3,
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Guwahati\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Guwahti',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAU\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 GAU',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia VTZ\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 VTZ',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia NDC\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 NDC',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXE\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 IXE',
        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Raipur\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Raipur',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia PAT\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 PAT',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia RPR\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 RPR',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Patna\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 patna',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Kolkata\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Kolkata',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia HYD\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Hyderabad',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Delhi\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Delhi',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Bhubaneswar\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Bhubaneshwar',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia BBI\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 BBI',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Surat\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Surat',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Indore\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Indore',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GOP\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 GOP',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Nagpur\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Nagpur',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia NAG\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Nagpur',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Vishakhapatnam\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Vishakhapatnam',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Mangalore\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Mangalore',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Mumbai\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Mumbai',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia KLH\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 KLH',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia MYQ\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 MYQ',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Kolhapur\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Kolhapur',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia JRG\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 JRG',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Ranchi\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Ranchi',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXR\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 IXR',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia JGB\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 JBG',
       '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Mysore\n\t\t\t\t\t\t\t\t\t\t\t\t' : '1 Mysore'})

# %%
df
# Out:
#           airline ch_code  num_code     from time_taken stop         to  \
# 0       Air India      AI       868    Delhi    02h 00m    0     Mumbai
# 1       Air India      AI       624    Delhi    02h 15m    0     Mumbai
# 2       Air India      AI       531    Delhi    24h 45m    1     Mumbai
# 3       Air India      AI       839    Delhi    26h 30m    1     Mumbai
# 4       Air India      AI       544    Delhi    06h 40m    1     Mumbai
# ...           ...     ...       ...      ...        ...  ...        ...
# 206769    Vistara      UK       832  Chennai    13h 50m    1  Hyderabad
# 206770    Vistara      UK       832  Chennai    13h 50m    1  Hyderabad
# 206771    Vistara      UK       826  Chennai    20h 35m    1  Hyderabad
# 206772    Vistara      UK       822  Chennai    23h 20m    1  Hyderabad
# 206773    Vistara      UK       824  Chennai    24h 25m    1  Hyderabad
#
#          price  day  month  year  Dep_hour  Dep_min  Arrival_hour  Arrival_min
# ...

# %%
df["airline"].value_counts()
# Out:
# Vistara      127859
# Air India     80894
# Indigo        43120
# GO FIRST      23177
# AirAsia       16098
# SpiceJet       9011
# StarAir          61
# Trujet           41
# Name: airline, dtype: int64

# %%
df['stop'].unique()
# Out:
# array([0, 1, '1 IDR', '1 IXU', '1 Chennai', '1 Lucknow', '1 STV',
#        '1 Hyderabad', '1 GAY', 3, '1 Guwahti', '1 GAU', '1 VTZ', '1 NDC',
#        '1 IXE', '1 Raipur', '1 PAT', '1 RPR', '1 patna', '1 Kolkata',
#        '1 Delhi', '1 Bhubaneshwar', '1 BBI', '1 Surat', '1 Indore',
#        '1 GOP', '1 Nagpur', '1 Vishakhapatnam', '1 Mangalore', '1 Mumbai',
#        '1 KLH', '1 MYQ', '1 Kolhapur', '1 JRG', '1 Ranchi', '1 IXR',
#        '1 JBG', '1 Mysore'], dtype=object)

# %%
df['price'].unique()
# Out:
# array(['25,612', '42,220', '44,450', ..., '2,932', '5,732', '6,541'],
#       dtype=object)

# %%
# remove commas and convert to integer
df['price'] = df['price'].str.replace(',', '').astype(int)

# print the dataframe to check the result
df
# Out:
#           airline ch_code  num_code     from time_taken stop         to  \
# 0       Air India      AI       868    Delhi    02h 00m    0     Mumbai
# 1       Air India      AI       624    Delhi    02h 15m    0     Mumbai
# 2       Air India      AI       531    Delhi    24h 45m    1     Mumbai
# 3       Air India      AI       839    Delhi    26h 30m    1     Mumbai
# 4       Air India      AI       544    Delhi    06h 40m    1     Mumbai
# ...           ...     ...       ...      ...        ...  ...        ...
# 206769    Vistara      UK       832  Chennai    13h 50m    1  Hyderabad
# 206770    Vistara      UK       832  Chennai    13h 50m    1  Hyderabad
# 206771    Vistara      UK       826  Chennai    20h 35m    1  Hyderabad
# 206772    Vistara      UK       822  Chennai    23h 20m    1  Hyderabad
# 206773    Vistara      UK       824  Chennai    24h 25m    1  Hyderabad
#
#         price  day  month  year  Dep_hour  Dep_min  Arrival_hour  Arrival_min
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300261 entries, 0 to 206773
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   airline       300261 non-null  object
#  1   ch_code       300261 non-null  object
#  2   num_code      300261 non-null  int64
#  3   from          300261 non-null  object
#  4   time_taken    300261 non-null  object
#  5   stop          300261 non-null  object
#  6   to            300261 non-null  object
#  7   price         300261 non-null  int32
#  8   day           300261 non-null  int64
#  9   month         300261 non-null  int64
#  10  year          300261 non-null  int64
#  11  Dep_hour      300261 non-null  int64
#  12  Dep_min       300261 non-null  int64
#  13  Arrival_hour  300261 non-null  int64
#  14  Arrival_min   300261 non-null  int64
# dtypes: int32(1), int64(8), object(6)
# memory usage: 35.5+ MB

# %%
print(df.columns)
# Out:
# Index(['airline', 'ch_code', 'num_code', 'from', 'time_taken', 'stop', 'to',
#        'price', 'day', 'month', 'year', 'Dep_hour', 'Dep_min', 'Arrival_hour',
#        'Arrival_min'],
#       dtype='object')

# %%
df["airline"].value_counts()
# Out:
# Vistara      127859
# Air India     80894
# Indigo        43120
# GO FIRST      23177
# AirAsia       16098
# SpiceJet       9011
# StarAir          61
# Trujet           41
# Name: airline, dtype: int64

# %%
# From graph we can see that Vastara Business have the highest Price.
# Apart from the first ad second Airline almost all are having similar median

# Airline vs Price
sns.catplot(y = "price", x = "airline", data = df.sort_values("price", ascending = False), kind="boxen", height = 6, aspect = 3)
plt.show()

# %%
plt.figure(figsize= (10,10))
sns.boxplot(data=df,orient="v")
# Out:
# <AxesSubplot:>

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
lower_bridge = Q1 - (1.5 * IQR)
upper_bridge = Q3 + (1.5 * IQR)
print(lower_bridge)
print(upper_bridge)
# Out:
# -51824.0
# 99128.0

# %%
df.loc[df['price']>=99128, 'price']=99128

# %%
plt.figure(figsize= (10,10))
sns.boxplot(data=df,orient="v")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize= (10,10))
sns.boxplot(data=df,y= "num_code",orient="v")
# Out:
# <AxesSubplot:ylabel='num_code'>

# %%
Q1 = df['num_code'].quantile(0.25)
Q3 = df['num_code'].quantile(0.75)
IQR = Q3 - Q1
lower_bridge = Q1 - (1.5 * IQR)
upper_bridge = Q3 + (1.5 * IQR)
print(lower_bridge)
print(upper_bridge)
# Out:
# 202.0
# 1362.0

# %%
df.loc[df['num_code']>=1362, 'num_code']=1362

# %%
df["ch_code"].value_counts()
# Out:
# UK    127859
# AI     80894
# 6E     43120
# G8     23177
# I5     16098
# SG      9011
# S5        61
# 2T        41
# Name: ch_code, dtype: int64

# %%
df["from"].value_counts()
# Out:
# Delhi        61345
# Mumbai       60903
# Bangalore    52106
# Kolkata      46347
# Hyderabad    40860
# Chennai      38700
# Name: from, dtype: int64

# %%
df["to"].value_counts()
# Out:
# Mumbai       59109
# Delhi        57361
# Bangalore    51112
# Kolkata      49535
# Hyderabad    42776
# Chennai      40368
# Name: to, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300261 entries, 0 to 206773
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   airline       300261 non-null  object
#  1   ch_code       300261 non-null  object
#  2   num_code      300261 non-null  int64
#  3   from          300261 non-null  object
#  4   time_taken    300261 non-null  object
#  5   stop          300261 non-null  object
#  6   to            300261 non-null  object
#  7   price         300261 non-null  int32
#  8   day           300261 non-null  int64
#  9   month         300261 non-null  int64
#  10  year          300261 non-null  int64
#  11  Dep_hour      300261 non-null  int64
#  12  Dep_min       300261 non-null  int64
#  13  Arrival_hour  300261 non-null  int64
#  14  Arrival_min   300261 non-null  int64
# dtypes: int32(1), int64(8), object(6)
# memory usage: 35.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300261 entries, 0 to 206773
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   airline       300261 non-null  object
#  1   ch_code       300261 non-null  object
#  2   num_code      300261 non-null  int64
#  3   from          300261 non-null  object
#  4   time_taken    300261 non-null  object
#  5   stop          300261 non-null  object
#  6   to            300261 non-null  object
#  7   price         300261 non-null  int32
#  8   day           300261 non-null  int64
#  9   month         300261 non-null  int64
#  10  year          300261 non-null  int64
#  11  Dep_hour      300261 non-null  int64
#  12  Dep_min       300261 non-null  int64
#  13  Arrival_hour  300261 non-null  int64
#  14  Arrival_min   300261 non-null  int64
# dtypes: int32(1), int64(8), object(6)
# memory usage: 35.5+ MB

# %%
df.head()
# Out:
#      airline ch_code  num_code   from time_taken stop      to  price  day  \
# 0  Air India      AI       868  Delhi    02h 00m    0  Mumbai  25612    2
# 1  Air India      AI       624  Delhi    02h 15m    0  Mumbai  25612    2
# 2  Air India      AI       531  Delhi    24h 45m    1  Mumbai  42220    2
# 3  Air India      AI       839  Delhi    26h 30m    1  Mumbai  44450    2
# 4  Air India      AI       544  Delhi    06h 40m    1  Mumbai  46690    2
#
#    month  year  Dep_hour  Dep_min  Arrival_hour  Arrival_min
# 0     11  2022        18        0            20            0
# 1     11  2022        19        0            21           15
# 2     11  2022        20        0            20           45
# 3     11  2022        21       25            23           55
# 4     11  2022        17       15            23           55

# %%
plt.figure(figsize=(12,6))
sns.barplot(df['day'], df['price'], palette='Set2')
plt.title('Days vs Price', size=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Md Imran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### From this plot we can observe that on day 2 has the highest price

# %%
plt.figure(figsize=(12,6))
sns.barplot(df['month'], df['price'], palette='Set2')
plt.title('Month vs Price', size=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Md Imran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### From this plot we can observe that in 2nd and 12th month has the highest price

# %%
plt.figure(figsize=(20,6))
df.airline.value_counts().plot(kind='barh', color=['C4', 'C5']); plt.title('airline')
# Out:
# Text(0.5, 1.0, 'airline')

# %% [markdown]
# #### Compare to other flights vastara has the highest price

# %%
plt.figure(figsize=(20,6))
df.to.value_counts().plot(kind='barh', color=['C3', 'C7']); plt.title('Airlines')
# Out:
# Text(0.5, 1.0, 'Airlines')

# %% [markdown]
# #### Most of the passengers were travelling to mumbai compare to other cities

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['from'], palette='Set2')
plt.title('Count of Source', size=30)
plt.ylabel("count", size=12)
plt.xlabel("from", size=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Md Imran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Most of the passengers are boarding from delhi and mumbai

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['to'], palette='Set2')
plt.title('Count of Source', size=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Md Imran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Most of the passengers were to mumbai and delhi

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['airline'], palette='Set2')
plt.title('Count of Airline', size=30)
plt.ylabel("count", size=12)
plt.xlabel("airline", size=12)
plt.xticks(rotation=75)
plt.show()
# Out:
# C:\Users\Md Imran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Vastara flights are more compare to other flights

# %%
df = df.drop(['time_taken'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300261 entries, 0 to 206773
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   airline       300261 non-null  object
#  1   ch_code       300261 non-null  object
#  2   num_code      300261 non-null  int64
#  3   from          300261 non-null  object
#  4   stop          300261 non-null  object
#  5   to            300261 non-null  object
#  6   price         300261 non-null  int32
#  7   day           300261 non-null  int64
#  8   month         300261 non-null  int64
#  9   year          300261 non-null  int64
#  10  Dep_hour      300261 non-null  int64
#  11  Dep_min       300261 non-null  int64
#  12  Arrival_hour  300261 non-null  int64
#  13  Arrival_min   300261 non-null  int64
# dtypes: int32(1), int64(8), object(5)
# memory usage: 33.2+ MB

# %%
categorical = list(df.select_dtypes('object').columns)
print(f"Categorical variables (columns) are: {categorical}")
# Out:
# Categorical variables (columns) are: ['airline', 'ch_code', 'from', 'stop', 'to']

# %%
cat = ['airline', 'from', 'stop', 'to', 'ch_code']
df = pd.get_dummies(df, columns=cat, drop_first=True)
df
# Out:
#         num_code  price  day  month  year  Dep_hour  Dep_min  Arrival_hour  \
# 0            868  25612    2     11  2022        18        0            20
# 1            624  25612    2     11  2022        19        0            21
# 2            531  42220    2     11  2022        20        0            20
# 3            839  44450    2     11  2022        21       25            23
# 4            544  46690    2     11  2022        17       15            23
# ...          ...    ...  ...    ...   ...       ...      ...           ...
# 206769       832   7697   31      3  2022         7        5            20
# 206770       832   7709   31      3  2022         7        5            20
# 206771       826   8640   31      3  2022        12       30             9
# 206772       822   8640   31      3  2022         9       45             9
# 206773       824   8640   31      3  2022        20       30            20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300261 entries, 0 to 206773
# Data columns (total 70 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   num_code               300261 non-null  int64
#  1   price                  300261 non-null  int32
#  2   day                    300261 non-null  int64
#  3   month                  300261 non-null  int64
#  4   year                   300261 non-null  int64
#  5   Dep_hour               300261 non-null  int64
#  6   Dep_min                300261 non-null  int64
#  7   Arrival_hour           300261 non-null  int64
#  8   Arrival_min            300261 non-null  int64
#  9   airline_AirAsia        300261 non-null  uint8
#  10  airline_GO FIRST       300261 non-null  uint8
#  11  airline_Indigo         300261 non-null  uint8
#  12  airline_SpiceJet       300261 non-null  uint8
#  13  airline_StarAir        300261 non-null  uint8
# ...

# %%
X = df.drop('price',axis=1).values
Y = df['price'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.20, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((240208, 69), (60053, 69))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.preprocessing import PolynomialFeatures
Poly = PolynomialFeatures(degree = 2)
X = Poly.fit_transform(X_train.reshape(-1,1))
X
# Out:
# array([[ 1.00000000e+00, -1.61312673e+00,  2.60217785e+00],
#        [ 1.00000000e+00,  1.46259651e+00,  2.13918856e+00],
#        [ 1.00000000e+00, -2.79660827e-01,  7.82101779e-02],
#        ...,
#        [ 1.00000000e+00, -1.49951898e-02,  2.24855718e-04],
#        [ 1.00000000e+00, -1.76073836e-01,  3.10019958e-02],
#        [ 1.00000000e+00, -8.60178130e-01,  7.39906416e-01]])

# %%
from sklearn.linear_model import LinearRegression 
reg = LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
#mean squared error(MSE)
from sklearn.metrics import r2_score

r2 = r2_score(Y_test,y_pred)
r2
# Out:
# 0.24900087004152738
