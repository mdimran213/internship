# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
df1
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df2 = pd.read_csv("Car details v3.csv")
df2
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df2 = df2.drop(['mileage','engine','max_power','torque','seats'],axis = 1)

# %%
df2
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner
# ...

# %%
df3 = pd.read_csv("car data.csv")
df3
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df3 = df3.drop("Present_Price",axis = True)
df3
# Out:
#     Car_Name  Year  Selling_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz  2014           3.35       27000    Petrol      Dealer
# 1        sx4  2013           4.75       43000    Diesel      Dealer
# 2       ciaz  2017           7.25        6900    Petrol      Dealer
# 3    wagon r  2011           2.85        5200    Petrol      Dealer
# 4      swift  2014           4.60       42450    Diesel      Dealer
# ..       ...   ...            ...         ...       ...         ...
# 296     city  2016           9.50       33988    Diesel      Dealer
# 297     brio  2015           4.00       60000    Petrol      Dealer
# 298     city  2009           3.35       87934    Petrol      Dealer
# 299     city  2017          11.50        9000    Diesel      Dealer
# 300     brio  2016           5.30        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# ...

# %%
df3
# Out:
#     Car_Name  Year  Selling_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz  2014           3.35       27000    Petrol      Dealer
# 1        sx4  2013           4.75       43000    Diesel      Dealer
# 2       ciaz  2017           7.25        6900    Petrol      Dealer
# 3    wagon r  2011           2.85        5200    Petrol      Dealer
# 4      swift  2014           4.60       42450    Diesel      Dealer
# ..       ...   ...            ...         ...       ...         ...
# 296     city  2016           9.50       33988    Diesel      Dealer
# 297     brio  2015           4.00       60000    Petrol      Dealer
# 298     city  2009           3.35       87934    Petrol      Dealer
# 299     city  2017          11.50        9000    Diesel      Dealer
# 300     brio  2016           5.30        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# ...

# %%
df1.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df3 = df3.rename(columns= {"Year":"year","Selling_Price":"selling_price","Kms_Driven":"km_driven","Fuel_Type":"fuel","Seller_Type":"seller_type","Transmission":"transmission","Owner":"owner","Car_Name":"name"})

# %%
df = pd.concat([df1,df2,df3])

# %%
df
# Out:
#                          name  year  selling_price  km_driven    fuel  \
# 0               Maruti 800 AC  2007       60000.00      70000  Petrol
# 1    Maruti Wagon R LXI Minor  2007      135000.00      50000  Petrol
# 2        Hyundai Verna 1.6 SX  2012      600000.00     100000  Diesel
# 3      Datsun RediGO T Option  2017      250000.00      46000  Petrol
# 4       Honda Amaze VX i-DTEC  2014      450000.00     141000  Diesel
# ..                        ...   ...            ...        ...     ...
# 296                      city  2016           9.50      33988  Diesel
# 297                      brio  2015           4.00      60000  Petrol
# 298                      city  2009           3.35      87934  Petrol
# 299                      city  2017          11.50       9000  Diesel
# 300                      brio  2016           5.30       5464  Petrol
#
#     seller_type transmission         owner
# 0    Individual       Manual   First Owner
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12769 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           12769 non-null  object
#  1   year           12769 non-null  int64
#  2   selling_price  12769 non-null  float64
#  3   km_driven      12769 non-null  int64
#  4   fuel           12769 non-null  object
#  5   seller_type    12769 non-null  object
#  6   transmission   12769 non-null  object
#  7   owner          12769 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 897.8+ KB

# %%
df.shape
# Out:
# (12769, 8)

# %%
df.describe()
# Out:
#                year  selling_price     km_driven
# count  12769.000000   1.276900e+04  1.276900e+04
# mean    2013.557444   5.776323e+05  6.781976e+04
# std        4.093730   7.345433e+05  5.325725e+04
# min     1983.000000   1.000000e-01  1.000000e+00
# 25%     2011.000000   2.250000e+05  3.400000e+04
# 50%     2014.000000   4.000000e+05  6.000000e+04
# 75%     2017.000000   6.500000e+05  9.000000e+04
# max     2020.000000   1.000000e+07  2.360457e+06

# %%
# Describing the categorical variables
df_categorical_variables = pd.DataFrame (df, columns= ['name', 'fuel', 'seller_type', 'transmission','owner'])
df_categorical_variables.describe()
# Out:
#                           name    fuel seller_type transmission        owner
# count                    12769   12769       12769        12769        12769
# unique                    2609       5           3            2            8
# top     Maruti Swift Dzire VDI  Diesel  Individual       Manual  First Owner
# freq                       198    6615       10116        11231         8121

# %%
# Deleting the "Car_Name" feature because, in the real world, the price of the car is not predicted based on the car's name
df11 = df.drop("name", axis= 1)

# %%
df11
# Out:
#      year  selling_price  km_driven    fuel seller_type transmission  \
# 0    2007       60000.00      70000  Petrol  Individual       Manual
# 1    2007      135000.00      50000  Petrol  Individual       Manual
# 2    2012      600000.00     100000  Diesel  Individual       Manual
# 3    2017      250000.00      46000  Petrol  Individual       Manual
# 4    2014      450000.00     141000  Diesel  Individual       Manual
# ..    ...            ...        ...     ...         ...          ...
# 296  2016           9.50      33988  Diesel      Dealer       Manual
# 297  2015           4.00      60000  Petrol      Dealer       Manual
# 298  2009           3.35      87934  Petrol      Dealer       Manual
# 299  2017          11.50       9000  Diesel      Dealer       Manual
# 300  2016           5.30       5464  Petrol      Dealer       Manual
#
#             owner
# 0     First Owner
# 1     First Owner
# 2     First Owner
# 3     First Owner
# 4    Second Owner
# ..            ...
# ...

# %%
# Checking duplicates
df11.loc[df11.duplicated()]
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 13    2007       60000.00      70000  Petrol  Individual       Manual
# 14    2007      135000.00      50000  Petrol  Individual       Manual
# 15    2012      600000.00     100000  Diesel  Individual       Manual
# 16    2017      250000.00      46000  Petrol  Individual       Manual
# 17    2014      450000.00     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8117  2015      625000.00      50000  Diesel  Individual       Manual
# 8126  2013      290000.00      25000  Diesel  Individual       Manual
# 8127  2013      290000.00      25000  Diesel  Individual       Manual
# 17    2016           7.75      43000  Diesel      Dealer       Manual
# 93    2015          23.00      40000  Diesel      Dealer    Automatic
#
#              owner
# 13     First Owner
# 14     First Owner
# 15     First Owner
# 16     First Owner
# 17    Second Owner
# ...

# %%
# Drop the duplicate values from the dataset
df22 = df11.drop_duplicates(keep='first')

# %%
df22.shape
# Out:
# (10140, 7)

# %%
# Calculate the "Age" of cars from the "Year" feature
latest_year = df22.year.max() +1
latest_year
# Out:
# 2021

# %%
df22["Age"] = latest_year - df22["year"]
df22.head(15)
# Out:
# C:\Users\Md Imran\AppData\Local\Temp\ipykernel_8484\3613200757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df22["Age"] = latest_year - df22["year"]
#     year  selling_price  km_driven    fuel seller_type transmission  \
# 0   2007        60000.0      70000  Petrol  Individual       Manual
# 1   2007       135000.0      50000  Petrol  Individual       Manual
# 2   2012       600000.0     100000  Diesel  Individual       Manual
# 3   2017       250000.0      46000  Petrol  Individual       Manual
# 4   2014       450000.0     141000  Diesel  Individual       Manual
# 5   2007       140000.0     125000  Petrol  Individual       Manual
# 6   2016       550000.0      25000  Petrol  Individual       Manual
# ...

# %%
# Changing columns order
change_column_order = ['year','Age','selling_price', 'fuel', 'seller_type','km_driven', 'transmission', 'owner']
df33 = df22.reindex(columns = change_column_order)
df33.head()
# Out:
#    year  Age  selling_price    fuel seller_type  km_driven transmission  \
# 0  2007   14        60000.0  Petrol  Individual      70000       Manual
# 1  2007   14       135000.0  Petrol  Individual      50000       Manual
# 2  2012    9       600000.0  Diesel  Individual     100000       Manual
# 3  2017    4       250000.0  Petrol  Individual      46000       Manual
# 4  2014    7       450000.0  Diesel  Individual     141000       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
df33.owner.unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car', 0, 1, 3], dtype=object)

# %%
df33.owner.nunique()
# Out:
# 8

# %% [markdown]
# ## Target variable

# %%
df33.selling_price
# Out:
# 0       60000.00
# 1      135000.00
# 2      600000.00
# 3      250000.00
# 4      450000.00
#          ...
# 296         9.50
# 297         4.00
# 298         3.35
# 299        11.50
# 300         5.30
# Name: selling_price, Length: 10140, dtype: float64

# %%
selling_price_mean_median = df33.selling_price.mean() - df33.selling_price.median()
print (selling_price_mean_median*1000)
# Out:
# 115566002.29782954

# %%
# plotting the target-year scatter graph
sns.scatterplot(data=df33, x="year", y="selling_price")
sns.set_style('darkgrid')
plt.title("selling price per year", size=10)
plt.ylabel("selling price", size=12)
plt.xlabel("year", size=12)
plt.show()

# %% [markdown]
# ####          From this plot we can observe that the year 2017  have the maximum selling price

# %%
# Number of records related to year of the car bought
plt.figure(figsize = (12, 10))
ax=sns.countplot(data=df33, x=df33.year)
sns.set_style('darkgrid')
for cont in ax.containers:
    ax.bar_label(cont)
plt.title('Number of records related to year of the car bought', size=10)
plt.yticks(size=14)
plt.xticks(size=8)
plt.grid(linestyle='-')

# Number of records for the age of car
plt.figure(figsize = (12, 10))
ax=sns.countplot(data=df33, x=df33.Age)
sns.set_style('darkgrid')
for cont in ax.containers:
    ax.bar_label(cont)
plt.title('Number of records for the age of car', size=10)
plt.yticks(size=12)
plt.xticks(size=12)
plt.grid(linestyle='-')
plt.show()

# %% [markdown]
# #### From this plot we can observe that the max cars have been bought in the year 2017
# #### And the cars of age 4 are maximum

# %%
plt.figure(figsize = (12, 10))
ax=sns.countplot(data=df33, x=df33.owner, ec='black')
sns.set_style('darkgrid')
for cont in ax.containers:
    ax.bar_label(cont)
plt.ylabel('Count of cars', size=12)
plt.yticks(size=12)
plt.xlabel('Owner', size=12)
plt.xticks(size=10)
plt.show()

# %% [markdown]
# #### From this count plot we can see the distribution of cars based on the owners

# %%
df_sym = pd.DataFrame(df33['owner'].value_counts())
df_sym.plot.pie(subplots=True, labels = df_sym.index.values, autopct='%1.1f%%', fontsize=10)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# #####    From this pie chart we can observe that maximum cars are of first owners

# %%
# plotting the target-Fuel type scatter graph
plt.figure(figsize = (12, 10))
sns.scatterplot(data=df33, x="fuel", y="selling_price")
sns.set_style('darkgrid')
plt.title("Fuel type vs. selling price", size=12)
plt.ylabel("selling price", size=12)
plt.xlabel("Fuel type", size=12)
plt.show()

# %% [markdown]
# #### From this plot we can observe that the petrol car has the highest selling price

# %%
# Count of cars by fuel type
plt.figure(figsize = (12, 10))
ax=sns.countplot(data=df33, x=df33.fuel, ec='black')
sns.set_style('darkgrid')
for cont in ax.containers:
    ax.bar_label(cont)
plt.yticks(size=12)
plt.xlabel('Fuel type', size=12)
plt.xticks(size=12)
plt.show()

# %% [markdown]
# #### From this graph we can observe that diesel cars are more

# %%
# plotting the target-Fuel type scatter graph
plt.figure(figsize = (12, 10))
sns.scatterplot(data=df33, x="seller_type", y="selling_price")
sns.set_style('darkgrid')
plt.title("Seller type vs. Selling price", size=12)
plt.ylabel("selling price", size=12)
plt.xlabel("Seller type", size=12)
plt.show()

# %% [markdown]
# #### From this graph we can see that the dealers cars are more and the highest selling price is of individual

# %%
# Count of cars by Seller type
plt.figure(figsize = (12, 10))
ax=sns.countplot(data=df33, x=df33.seller_type, ec='black')
sns.set_style('darkgrid')
for cont in ax.containers:
    ax.bar_label(cont)
plt.ylabel('Count of cars', size=12)
plt.yticks(size=12)
plt.xlabel('Seller type', size=12)
plt.xticks(size=12)
plt.show()

# %% [markdown]
# ####  From this plot observe that individual sellers are more

# %%
# plotting the target-Fuel type scatter graph
plt.figure(figsize = (12, 10))
sns.scatterplot(data=df33, x="transmission", y="selling_price")
sns.set_style('darkgrid')
plt.title("Transmission vs. Selling price", size=12)
plt.ylabel("Selling price", size=12)
plt.xlabel("transmission", size=12)
plt.show()

# %% [markdown]
# #### Automatic cars have more selling price as compared to manual cars

# %%
# Count of cars by Transmission
plt.figure(figsize = (10, 8))
ax=sns.countplot(data=df33, x=df33.transmission, ec='black')
sns.set_style('darkgrid')
for cont in ax.containers:
    ax.bar_label(cont)
plt.ylabel('Count of cars', size=12)
plt.yticks(size=12)
plt.xlabel('Transmission', size=12)
plt.xticks(size=12)
plt.show()

# %% [markdown]
# ####   From tis plot observe that manual cars more

# %%
plt.figure(figsize = (10, 8))
a=df33.groupby('transmission')['selling_price'].mean()
ax = a.plot.bar(ec='black', width=.7, color="m")
for container in ax.containers:
    ax.bar_label(container)
plt.title('transmission vs. Average Selling price', size=10)
plt.ylabel("selling price", size=8)
plt.xlabel('transmission', size=8)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ####  From this plot observe that automatic cars selling price is more

# %%
# Due to the creation of high multicollinearity between 'Year' & 'Age' features, one of those should remove from the dataset.
df44 = df33.drop("year", axis= 1)
df44.head()
# Out:
#    Age  selling_price    fuel seller_type  km_driven transmission  \
# 0   14        60000.0  Petrol  Individual      70000       Manual
# 1   14       135000.0  Petrol  Individual      50000       Manual
# 2    9       600000.0  Diesel  Individual     100000       Manual
# 3    4       250000.0  Petrol  Individual      46000       Manual
# 4    7       450000.0  Diesel  Individual     141000       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
df_num = df44.select_dtypes(exclude='object')
df_obj = df44.select_dtypes(include='object')

# %%
df_obj = pd.get_dummies(df_obj, drop_first=True)

# %%
Final_df = pd.concat([df_num, df_obj], axis=1)

# %%
Cars = Final_df

# %%
Cars.head(15)
# Out:
#     Age  selling_price  km_driven  fuel_Diesel  fuel_Electric  fuel_LPG  \
# 0    14        60000.0      70000            0              0         0
# 1    14       135000.0      50000            0              0         0
# 2     9       600000.0     100000            1              0         0
# 3     4       250000.0      46000            0              0         0
# 4     7       450000.0     141000            1              0         0
# 5    14       140000.0     125000            0              0         0
# 6     5       550000.0      25000            0              0         0
# 7     7       240000.0      60000            0              0         0
# 8     6       850000.0      25000            0              0         0
# 9     4       365000.0      78000            0              0         0
# 10    6       260000.0      35000            0              0         0
# 11    7       250000.0     100000            0              0         0
# ...

# %%
Cars.shape
# Out:
# (10140, 17)

# %%
X = Cars.drop('selling_price', axis=1)
y = Cars['selling_price'].values.reshape(-1,1)

# %%
print("X=",X.shape,"\ny=", y.shape)
# Out:
# X= (10140, 16)
# y= (10140, 1)

# %%
Cars.columns
# Out:
# Index(['Age', 'selling_price', 'km_driven', 'fuel_Diesel', 'fuel_Electric',
#        'fuel_LPG', 'fuel_Petrol', 'seller_type_Individual',
#        'seller_type_Trustmark Dealer', 'transmission_Manual', 'owner_1',
#        'owner_3', 'owner_First Owner', 'owner_Fourth & Above Owner',
#        'owner_Second Owner', 'owner_Test Drive Car', 'owner_Third Owner'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0)

# %%
print("X_train=",X_train.shape,"\nx_test=", X_test.shape)
# Out:
# X_train= (8112, 16)
# x_test= (2028, 16)

# %%
# Importing the required library
from sklearn import preprocessing

# %% [markdown]
# ####   StandardScaler is used to resize the distribution of values ​​so that the mean of the observed values ​​is 0 and the standard deviation is 1

# %%
# StandardScaler
Scaler_2 = preprocessing.StandardScaler()
Norm2 = Scaler_2.fit_transform (Cars)
Norm2_Cars = pd.DataFrame (Norm2, columns=['Age', 'selling_price', 'km_driven', 'fuel_Diesel', 'fuel_Electric',
       'fuel_LPG', 'fuel_Petrol', 'seller_type_Individual',
       'seller_type_Trustmark Dealer', 'transmission_Manual', 'owner_1',
       'owner_3', 'owner_First Owner', 'owner_Fourth & Above Owner',
       'owner_Second Owner', 'owner_Test Drive Car', 'owner_Third Owner'])

# %%
Norm2_Cars
# Out:
#             Age  selling_price  km_driven  fuel_Diesel  fuel_Electric  \
# 0      1.500534      -0.815302  -0.032784    -1.030240      -0.009931
# 1      1.500534      -0.673285  -0.390511    -1.030240      -0.009931
# 2      0.294665       0.207220   0.503806     0.970648      -0.009931
# 3     -0.911204      -0.455526  -0.462056    -1.030240      -0.009931
# 4     -0.187683      -0.076814   1.237146     0.970648      -0.009931
# ...         ...            ...        ...          ...            ...
# 10135 -0.670030      -0.928898  -0.676907     0.970648      -0.009931
# 10136 -0.428857      -0.928908  -0.211647    -1.030240      -0.009931
# 10137  1.018186      -0.928910   0.287990    -1.030240      -0.009931
# 10138 -0.911204      -0.928894  -1.123850     0.970648      -0.009931
# 10139 -0.670030      -0.928906  -1.187096    -1.030240      -0.009931
#
#        fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0     -0.076502     1.062292                0.434609
# ...
